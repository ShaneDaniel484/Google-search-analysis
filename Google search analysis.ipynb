# %% [markdown]
# # Installing PYTRENDS

# %%
# !pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\aaron\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\aaron\anaconda3\lib\site-packages (from pytrends) (1.3.4)
# Requirement already satisfied: requests>=2.0 in c:\users\aaron\anaconda3\lib\site-packages (from pytrends) (2.26.0)
# Requirement already satisfied: lxml in c:\users\aaron\anaconda3\lib\site-packages (from pytrends) (4.6.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\aaron\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\aaron\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\aaron\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aaron\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aaron\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aaron\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaron\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2021.10.8)

# %% [markdown]
# # importing necessary libraries

# %%
import pandas as pd                    #for analysing data
from pytrends.request import TrendReq  #get the dataframe from google api
import matplotlib.pyplot as plt        #to visulize the data
trends=TrendReq()

# %% [markdown]
# # getting keyword from the user and displaying its trend-country wise

# %%
key=input("ENTER THE KEYWORD TO GET THE DATA: ")
trends.build_payload(kw_list=[key])                # Preparing Keywords to get the data for
data = trends.interest_by_region()                 # Returns data for where the keyword is most searched
data = data.sort_values(by=key, ascending=False)   #displays the dataframe in a table
data = data.head(10)                               #displays the first 10 data with their corresponding values
print(data)
# Out:
# ENTER THE KEYWORD TO GET THE DATA: KGF 2
#                       KGF 2
# geoName
# Nepal                   100
# India                    86
# Bangladesh               67
# Pakistan                 65
# Sri Lanka                42
# United Arab Emirates     31
# Qatar                    27
# Oman                     21
# Kuwait                   12
# Malaysia                  7

# %% [markdown]
# # plotting it in a bar graph

# %%
data.reset_index().plot(x="geoName", y=key, figsize=(25,15), kind="bar")  #assigning values to x and y axis
plt.style.use('fivethirtyeight')                                          #choosing the graph sheet style
plt.show()                                                                # visualizing the data

# %% [markdown]
# # plotting the line graph based on the trend for the last 5 years

# %%
data = TrendReq(hl='en-US', tz=360)                 #importing dataframe from google api
data.build_payload(kw_list=[key])                   
data = data.interest_over_time()                    #Returns historical, indexed data
fig, ax = plt.subplots(figsize=(25, 15))
data[key].plot()                                    #plotting the graph for the keywords
plt.style.use('fivethirtyeight')
plt.title(f'Total Google Searches for {key}', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()                                         # visualizing the data
